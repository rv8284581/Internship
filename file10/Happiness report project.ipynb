# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import seaborn as sns

from pandas.plotting import scatter_matrix

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv', sep=',')
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df1.isnull().values.any()
# Out:
# False

# %%
df1.isnull().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
sns.set(style='ticks',color_codes=True)
g=sns.pairplot(df1,kind="reg")

# %%
corrmat=df1.corr()
sns.heatmap(corrmat, vmax=.8,square=True)
# Out:
# <AxesSubplot:>

# %%
df1=df1.groupby(['Country'], sort=False)['Happiness Score'].max().head(10)
df1
# Out:
# Country
# Switzerland    7.587
# Iceland        7.561
# Denmark        7.527
# Norway         7.522
# Canada         7.427
# Finland        7.406
# Netherlands    7.378
# Sweden         7.364
# New Zealand    7.286
# Australia      7.284
# Name: Happiness Score, dtype: float64

# %%
df1.shape
# Out:
# (10,)

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.hist(df1)
# Out:
# (array([[ 17.,  17.,  17.,  16.,  17.,  17.,  16.,  17.,  17.,   7.],
#         [  0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 158.],
#         [ 16.,  17.,  17.,  16.,  17.,  17.,  16.,  17.,  17.,   8.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [158.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]]),
#  array([0.0, 16.7, 33.4, 50.099999999999994, 66.8, 83.5,
# ...

# %%
ax=sns.countplot(x='Country', data=df1)
print(df1['Country'].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13808\3277179466.py in <module>
# ----> 1 Counrty.dtypes
#
# NameError: name 'Counrty' is not defined

# %%
df1.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
sns.heatmap(df1.isnull(),cmap="cool_r")
# Out:
# <AxesSubplot:>

# %%
categorical_col=[]
for i in df1.dtypes.index:
    if df1.dtypes [i] == "Object":
        categorical_col.append(i)
        
print("categorical columns:", categorical_col)
print ("\n")
# Out:
# categorical columns: []

# %%
numerical_col=[]
for i in df1.dtypes.index:
    if df1.dtypes [i]!= "Object":
        numerical_col.append(i)
        
print("numerical columns:", numerical_col)
# Out:
# numerical columns: ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
df1.nunique().to_frame ("No. of unique values")
# Out:
#                                No. of unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
df1["Happiness Score"].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df1["Happiness Score"].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
df1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(10,6), facecolor='white')
plotnumber=1
for col in categorical_col:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.distplot(df1[col],color='m')
        plt.xlable(col,fontsize=12)
        plpt.yticks(rotation=0, fontsize =10)
    plotnumber+=1
    
plt.tight_layout()

# %%
plt.title('Comparision between Happiness Score and Happiness Rank')
sns.stripplot(x='Happiness Score', y='Happiness Rank', data=df1)
plt.show()

# %%
plt.title('Comparision between Family and Country')
sns.scatterplot(x='Family', y='Country', data=df1,)
plt.show()

# %%
plt.title('Comparision between Happiness Score and Happiness Rank')
sns.scatterplot(x='Happiness Score', y='Happiness Rank', data=df1, hue='Freedom', palette='bright')
plt.show()

# %%
plt.title('Comparision between Happiness Score and Happiness Rank')
sns.catplot(x='Country',col='Family', data=df1, kind='count', palette = 'spring_r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_252\1467111098.py in <module>
#       1 plt.title('Comparision between Happiness Score and Happiness Rank')
# ----> 2 sns.catplot(x='Country',col='Family', data=df1, kind='count', palette = 'spring_r')
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.catplot(x='Country', col='Family', data=df1, palette='twilight_shifted', kind='count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_252\593240998.py in <module>
# ----> 1 sns.catplot(x='Country', col='Family', data=df1, palette='twilight_shifted', kind='count')
#       2 plt.show()
#       3
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3842
#    3843     # Initialize the facets
# ...

# %% [markdown]
# # Titanic

# %%
import pandas as ps
import numpy as np
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style="whitegrid")

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data=data.groupby(["Sex", "Pclass"], as_index=False)["Survived"].sum()

g=sns.catplot(data=data, kind='bar',
             x='Pclass',y='Survived', hue='Sex',
             palette='dark', alpha=.9, height=6
).set(title="Number of titanic survivors by class and sex")

g.set_axis_labels("Class", "Number of Survivors")

# %%
data=data.groupby(['Sex','Pclass'], as_index=False)["Survived"].apply(lambda x:
                                                                     100*x.sum()/x.count())
g=sns.catplot(data=data, kind='bar',
              x='Pclass', y='Survived', hue='Sex',
             palette='dark', alpha=.9, height=8
             
).set(title="Percentage of Titanic Survivors by class and sex")
g.set_axis_labels("Class", "Percentage of Survivors [%]")

# %%
sns.catplot(data=data, x="Pclass", y="Fare", hue="Sex", kind="box", height=7)

# %%
data_clean=data
data_clean.dropna(subset=['Age'], inplace=True)
sns.histplot(data=data_clean, x='Age', hue='Sex', bins=20)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=data_clean, x='Age', hue='Pclass', bins=20)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

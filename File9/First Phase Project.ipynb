# %% [markdown]
# # Red & White wine

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
R=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
W=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')

# %%
R.shape
# Out:
# (1599, 12)

# %%
W.shape
# Out:
# (1599, 12)

# %%
R.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
R.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
W.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
R.duplicated().sum()
# Out:
# 240

# %%
W.duplicated().sum()
# Out:
# 240

# %%
R.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
W.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
R['quality'].unique(),W['quality'].nunique()
# Out:
# (array([5, 6, 7, 4, 8, 3], dtype=int64), 6)

# %%
R['density'].mean()
# Out:
# 0.9967466791744831

# %%
W['density'].mean()
# Out:
# 0.9967466791744831

# %%
color_red=np.repeat('Red',R.shape[0])
color_white=np.repeat('White',W.shape[0])

# %%
color_red
# Out:
# array(['Red', 'Red', 'Red', ..., 'Red', 'Red', 'Red'], dtype='<U3')

# %%
color_white
# Out:
# array(['White', 'White', 'White', ..., 'White', 'White', 'White'],
#       dtype='<U5')

# %%
R['color']=color_red
R.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
W['color']=color_white
W.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  color
# 0      9.4        5  White
# 1      9.8        5  White
# ...

# %%
R.rename(columns={'chlorides':'Chlorides'},inplace=True)

# %%
R
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  Chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df=R.append(W)

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color  chlorides
# 0      9.4        5   Red        NaN
# ...

# %%
wine_df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  Chlorides  \
# 1594            6.2             0.600         0.08             2.0        NaN
# 1595            5.9             0.550         0.10             2.2        NaN
# 1596            6.3             0.510         0.13             2.3        NaN
# 1597            5.9             0.645         0.12             2.0        NaN
# 1598            6.0             0.310         0.47             3.6        NaN
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  color  chlorides
# ...

# %%
wine_df["fixed acidity"].hist();

# %%
wine_df['alcohol'].hist();

# %%
wine_df['pH'].hist();

# %%
wine_df['density'].hist();

# %%
wine_df['quality'].hist();

# %%
wine_df.plot(y='quality',x='volatile acidity',kind='scatter');

# %%
wine_df.plot(x='pH',y='quality',kind='scatter');

# %%
wine_df.plot(x='alcohol',y='quality',kind='scatter');

# %%
wine_df.plot(x='residual sugar',y='quality',kind='scatter');

# %%
corr=wine_df.corr()
plt.figure(figsize=[10,8])
sns.heatmap(corr,annot=True)
plt.xticks(rotation=45)
plt.title("Heatmap of Correlation Coefficient for wine Feature Variable",fontsize=12);

# %%
wine_df.groupby('color')['quality'].mean()
# Out:
# color
# Red      5.636023
# White    5.636023
# Name: quality, dtype: float64

# %%
wine_df['pH'].describe()
# Out:
# count    3198.000000
# mean        3.311113
# std         0.154362
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
bin_edges=[2.72,3.11,3.21,3.32,4.01]

# %%
bin_names=['high','moderately high','medium','low']

# %%
wine_df['acidity_levels']=pd.cut(wine_df['pH'],bins=bin_edges,labels=bin_names)

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color  chlorides   acidity_levels
# ...

# %%
wine_df.groupby('acidity_levels')['quality'].mean()
# Out:
# acidity_levels
# high               5.692308
# moderately high    5.676157
# medium             5.670429
# low                5.588798
# Name: quality, dtype: float64

# %%
wine_df['alcohol'].median()
# Out:
# 10.2

# %%
low_alcohol=wine_df.query('alcohol < 10.3')

high_alcohol=wine_df.query('alcohol>=10.3')

num_samples=wine_df.shape[0]
num_samples==low_alcohol['quality'].count()+high_alcohol['quality'].count()
# Out:
# True

# %%
low_alcohol['quality'].mean()
# Out:
# 5.324228028503563

# %%
high_alcohol['quality'].mean()
# Out:
# 5.982826948480845

# %%
wine_df['residual sugar'].median()
# Out:
# 2.2

# %%
low_sugar=wine_df.query('residual sugar <3.0')
high_sugar=wine_df.query('residual sugar >=3.0')

num_samples==low_sugar['quality'].count() + high_sugar['quality'].count()
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\Akshu\AppData\Local\Temp\ipykernel_11252\1235104003.py", line 1, in <module>
#     low_sugar=wine_df.query('residual sugar <3.0')
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 4111, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 4240, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 351, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 811, in __init__
#     self.terms = self.parse()
#
# ...

# %%
median=wine_df['alcohol'].median()

low=wine_df.query('alcohol<{}'.format(median))
high=wine_df.query('alcohol>={}'.format(median))

mean_quality_low_alcohol=low['quality'].mean()
mean_quality_high_alcohol=high['quality'].mean()

# %%
locations=[1,2]
heights=[mean_quality_low_alcohol,mean_quality_high_alcohol]
labels=['Low','High']

plt.bar(locations ,heights)
plt.title('Average Quality Rating by Alcohol Content')
plt.xlable('Alcohol Content')
plt.ylabel('Average Quality Rating');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11252\2720176261.py in <module>
#       5 plt.bar(locations ,heights)
#       6 plt.title('Average Quality Rating by Alcohol Content')
# ----> 7 plt.xlable('Alcohol Content')
#       8 plt.ylabel('Average Quality Rating');
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
median=wine_df['residual sugar'].median()

low_sugar=wine_df.query("residual sugar < {}".format(median))
high_sugar = wine_df.query("residual sugar >={}".format(median))


mean_quality_low_sugar=low_sugar['quality'].mean()
mean_quality_high_sugar = high_sugar['quality'].mean()
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\Akshu\AppData\Local\Temp\ipykernel_11252\1009401156.py", line 3, in <module>
#     low_sugar=wine_df.query("residual sugar < {}".format(median))
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 4111, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 4240, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 351, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 811, in __init__
#     self.terms = self.parse()
#
# ...

# %%
locations = [1,2]
heights = [mean_quality_low_sugar,mean_quality_high_sugar]
labels=['low','high']

plt.bar(locations,heights,tick_label=labels)
plt.title('Average Quaity Ratings by Residual sugar')
plt.xlabel('Residual sugar')
plt.ylabel('Average Quality Ratings ');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11252\734097125.py in <module>
#       1 locations = [1,2]
# ----> 2 heights = [mean_quality_low_sugar,mean_quality_high_sugar]
#       3 labels=['low','high']
#       4
#       5 plt.bar(locations,heights,tick_label=labels)
#
# NameError: name 'mean_quality_low_sugar' is not defined

# %%
acidity_level_mean=wine_df.groupby('acidity_levels')['quality'].mean()
acidity_level_mean
# Out:
# acidity_levels
# high               5.692308
# moderately high    5.676157
# medium             5.670429
# low                5.588798
# Name: quality, dtype: float64

# %%
locations=[2,3,4,1]
heights=acidity_level_mean
labels=['low','median','moderately high','high']

plt.bar(locations,heights,tick_label=labels)
plt.title('Average Quality ratings by Acidity level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Rating');

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
locations=[1,2]
heights=[mean_quality_low_sugar,mean_quality_high_sugar]

plt.plot(locations,heights)
plt.title('Average Quality Ratings by Residual Sugar')
plt.xlabel('Residual Sugar')
plt.ylabel('Average Quality Rating');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11252\465481691.py in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 locations=[1,2]
# ----> 4 heights=[mean_quality_low_sugar,mean_quality_high_sugar]
#       5
#       6 plt.plot(locations,heights)
#
# NameError: name 'mean_quality_low_sugar' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
locations=[1,2,3,4]
heights=[5.859593,5.850832,5.784540,5.783343]

plt.plot(locations, heights)
plt.title('Average Quality Ratings by Acidity Level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Ratings');

# %% [markdown]
# #  Insaurance

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import LabelEncoder
import copy

# %%
df_ins=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
df_ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_ins.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_ins.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_ins.shape
# Out:
# (1338, 7)

# %%
df_ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df_ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df_ins.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
for i in df_ins.columns:
    print(df_ins[i].value_counts())
    print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %%
sns.set(style="whitegrid")
sns.boxplot(df_ins["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(df_ins["bmi"])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.boxplot(df_ins["children"])
# Out:
# <AxesSubplot:xlabel='children'>

# %%
sns.boxplot(df_ins["charges"])
# Out:
# <AxesSubplot:xlabel='charges'>

# %%
df_ins.boxplot(figsize=(24,8))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,3,1)
plt.hist(df_ins.bmi,color="lightblue", edgecolor="black", alpha=0.7)
plt.xlabel("bmi")

plt.subplot(3,3,2)
plt.hist(df_ins.age, color="lightblue", edgecolor="black", alpha=0.7)
plt.xlabel("age")

plt.subplot(3,3,3)
plt.hist(df_ins.charges, color="lightblue", edgecolor="black", alpha=0.7)

plt.show()

# %%
sns.distplot(df_ins["age"], kde=True, rug=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(df_ins["bmi"], kde=True, rug=True)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df_ins["charges"], kde=True, rug=True)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Density'>

# %%
Skewness = pd.DataFrame({'Skewness': [stats.skew(df_ins.bmi),stats.skew(df_ins.age),stats.skew(df_ins.charges)]},index=["bmi","age","charges"])

Skewness
# Out:
#          Skewness
# bmi      0.283729
# age      0.055610
# charges  1.514180

# %%
 np.subtract(*np.percentile(df_ins["charges"], [75,25]))
# Out:
# 11899.625365

# %%
q25, q75 = np.percentile(df_ins['charges'],25),np.percentile(df_ins['charges'],75)
iqr=q75-q25
cut_off= (iqr) * (1.5)
lower,upper=q25-cut_off, q75+cut_off
outliers=[x for x in df_ins['charges']if x < lower or x > upper]
print("Identified Outlier for Charge out of 1138:%d" % (len(outliers)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\1222591321.py in <module>
#       4 lower,upper=q25-cut_off, q75+cut_off
#       5 outliers=[x for x in df_ins['charges']if x < lower or x > upper]
# ----> 6 print("Identified Outlier for Charge out of 1138:%d" % (len(outliers)))
#
# TypeError: 'numpy.float64' object is not callable

# %%
q25, q75 = np.percentile(df_ins['bmi'], 25), np.percentile(df_ins['bmi'], 75)
iqr = q75 - q25
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off

outliers = [x for x in df_ins['bmi'] if x < lower or x > upper]
print ('Identified outliers for bmi out of 1338 records: %d' % len(outliers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\1586550086.py in <module>
#       5
#       6 outliers = [x for x in df_ins['bmi'] if x < lower or x > upper]
# ----> 7 print ('Identified outliers for bmi out of 1338 records: %d' % len(outliers))
#
# TypeError: 'numpy.float64' object is not callable

# %%
q25, q75 = np.percentile(df_Insurance['bmi'], 25), np.percentile(df_Insurance['bmi'], 75)
iqr = q75 - q25
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off

outliers = [x for x in df_Insurance['bmi'] if x < lower or x > upper]
print('Identified outliers for bmi out of 1338 records: %d' % len(outliers))

# %%
q25, q75 = np.percentile(df_Insurance['age'], 25), np.percentile(df_Insurance['age'], 75)
iqr = q75 - q25
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off

outliers = [x for x in df_Insurance['age'] if x < lower or x > upper]
print('Identified outliers for age out of 1338 records: %d' % len(outliers))

# %%
sns.boxplot(x='children', y='charges', data=df_ins)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
sns.boxplot(x='sex', y='charges', data=df_ins)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
sns.boxplot(x='region', y='charges', data=df_ins)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sns.boxplot(x='smoker', y='charges', data=df_ins)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sns.countplot(df_ins['children'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
sns.countplot(df_ins['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(df_ins['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(df_ins['smoker'],hue = df_ins['sex'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(df_ins['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
insurance_df_encoded = copy.deepcopy(df_ins)
insurance_df_encoded.loc[:,['sex','smoker','region']]=df_ins.loc[:,['sex','smoker','region']].apply(LabelEncoder().fit_transform)
sns.pairplot(insurance_df_encoded)
plt.show()

# %%
df_ins.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df_ins.age, df_ins.charges, hue = df_ins.smoker, palette = ['red','green'], alpha=0.6)
plt.show()

# %%
A="Chargesof smoker and non-smoker are same"
B="Charges of smoker and non-smoker are not the same"

x=np.array(df_ins[df_ins.smoker == 'yes'].charges)
y=np.array(df_ins[df_ins.smoker == 'no'].charges)

t, p_value = stats.ttest_ind(x,y, axis =0)
print(p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\204755865.py in <module>
#       6
#       7 t, p_value = stats.ttest_ind(x,y, axis =0)
# ----> 8 print(p_value)
#
# TypeError: 'numpy.float64' object is not callable

# %%
df_ins.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(df_ins.age, df_ins.charges, hue=df_ins.sex)
plt.show()

# %%
A="Gender has no impact on bmi"
B="Gender has an impact on bmi"

x = np.array(df_ins[df_ins.sex == 'male'].bmi)
y = np.array(df_ins[df_ins.sex == 'female'].bmi)

t, p_value = stats.ttest_ind(x,y, axis = 0)
print(p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\445673769.py in <module>
#       6
#       7 t, p_value = stats.ttest_ind(x,y, axis = 0)
# ----> 8 print(p_value)
#
# TypeError: 'numpy.float64' object is not callable

# %%
A = "Genderhas no effect on smoking habits"
B = "Gender has an effect on smoking habits"

crosstab = pd.crosstab(df_ins['sex'],df_ins['smoker'])
chi, P_value, dof, expected = stats.chi2_contingency(crosstab)
print(p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\2088468689.py in <module>
#       4 crosstab = pd.crosstab(df_ins['sex'],df_ins['smoker'])
#       5 chi, P_value, dof, expected = stats.chi2_contingency(crosstab)
# ----> 6 print(p_value)
#
# TypeError: 'numpy.float64' object is not callable

# %%
A= "No. of children has no effect on bmi"
B = "No. of children has an effect on bmi"

female_df = copy.deepcopy(df_ins[df_ins['sex'] == 'female'])

zero = female_df[female_df.children == 0]['bmi']
one = female_df[female_df.children == 1]['bmi']
two = female_df[female_df.children == 2]['bmi']

f_stat, p_value = stats.f_oneway(zero,one,two)
print(p_value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6780\264816757.py in <module>
#       9
#      10 f_stat, p_value = stats.f_oneway(zero,one,two)
# ---> 11 print(p_value)
#
# TypeError: 'numpy.float64' object is not callable
